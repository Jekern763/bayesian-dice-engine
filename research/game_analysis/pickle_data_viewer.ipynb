# %%
import pandas as pd

df = pd.read_pickle("../data/game_analysis/analysis_by_history.pkl")

df
# Out:
#     history  num_dice  num_sides  depth  probability_in_depth  \
# 0      (1,)         1          1      1              1.000000
# 1        ()         1          1      0              1.000000
# 2        ()         2          1      0              1.000000
# 3      (2,)         2          1      1              1.000000
# 4        ()         3          1      0              1.000000
# ..      ...       ...        ...    ...                   ...
# 86    (10,)         7          2      1              0.273438
# 87    (13,)         7          2      1              0.054688
# 88       ()         7          2      0              1.000000
# 89     (9,)         7          2      1              0.164062
# 90  (7, 14)         7          2      2              0.007812
#
#                                                states  num_states  entropy  \
# 0                          {GameState(dice=((),)): 1}           1      0.0
# ...
