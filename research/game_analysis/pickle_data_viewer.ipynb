# %%
import pandas as pd

df = pd.read_pickle("../data/game_analysis/analysis_by_history.pkl")

df
# Out:
#                   history  num_dice  num_sides  depth  probability_in_depth  \
# 0                    (1,)         1          1      1              1.000000
# 1                      ()         1          1      0              1.000000
# 2                  (1, 2)         1          2      2              0.500000
# 3                    (2,)         1          2      1              0.500000
# 4                  (2, 1)         1          2      2              0.500000
# ...                   ...       ...        ...    ...                   ...
# 145833   (4, 6, 8, 11, 5)         2          6      5              0.000015
# 145834   (8, 2, 7, 10, 5)         2          6      5              0.000015
# 145835   (2, 8, 6, 4, 11)         2          6      5              0.000004
# 145836  (10, 6, 2, 7, 11)         2          6      5              0.000008
# 145837   (11, 6, 7, 5, 7)         2          6      5              0.000046
#
# ...
