# %%
from game_metrics import generate_metrics

# %%
df = generate_metrics(
    range(2, 3),
    range(6, 7),
)

import pandas as pd

# 1. Force all columns to show (removes the ...)
pd.set_option('display.max_columns', None)

# 2. Prevent text from being cut off inside cells
pd.set_option('display.max_colwidth', None)

# 3. View the DataFrame (use display() to force a fresh render)
display(df)
# Out:
#    num_dice  num_sides  depth  num_histories  num_states  mean_states  \
# 0         2          6      0              1           1     1.000000
# 1         2          6      1             11          21     1.909091
# 2         2          6      2            115         120     3.869565
# 3         2          6      3           1117         210     5.401970
# 4         2          6      4           9593         120     4.269884
# 5         2          6      5          62663          21     1.591609
# 6         2          6      6          62663           1     1.000000
#
#    median_states  min_states  max_states  mad_states  mean_entropy  \
# 0              1           1           1         0.0      0.000000
# 1              2           1           3         1.0      0.795899
# 2              3           1          10         2.0      1.629992
# 3              4           1          20         2.0      2.008035
# 4              4           1          15         2.0      1.700761
# 5              1           1           3         0.0      0.515944
# 6              1           1           1         0.0      0.000000
#
#    max_entropy  min_entropy  median_entropy  mad_entropy  mean_norm_entropy  \
# 0     0.000000          0.0        0.000000     0.000000           0.000000
# 1     1.584963          0.0        1.000000     0.584963           0.636364
# 2     3.321928          0.0        1.584963     0.736966           0.823359
# 3     4.277613          0.0        2.000000     0.973557           0.858828
# 4     3.766968          0.0        1.918296     0.918296           0.811098
# 5     1.584963          0.0        0.000000     0.000000           0.454580
# 6     0.000000          0.0        0.000000     0.000000           0.000000
#
#    median_norm_entropy  min_norm_entropy  max_norm_entropy  mad_norm_entropy  \
# 0             0.000000               0.0               0.0      0.000000e+00
# 1             1.000000               0.0               1.0      0.000000e+00
# 2             1.000000               0.0               1.0      0.000000e+00
# 3             1.000000               0.0               1.0      1.110223e-16
# 4             0.987807               0.0               1.0      1.219252e-02
# 5             0.000000               0.0               1.0      0.000000e+00
# 6             0.000000               0.0               0.0      0.000000e+00
#
#    mean_top_state_prob  median_top_state_prob  min_top_state_prob  \
# 0             1.000000               1.000000            1.000000
# 1             0.636364               0.500000            0.333333
# 2             0.416467               0.333333            0.100000
# 3             0.354686               0.250000            0.066667
# 4             0.430964               0.333333            0.100000
# 5             0.789977               1.000000            0.333333
# 6             1.000000               1.000000            1.000000
#
#    max_top_state_prob  mad_top_state_prob  weighted_mean_states  \
# 0                 1.0            0.000000              1.000000
# 1                 1.0            0.166667              2.238095
# 2                 1.0            0.166667              5.434409
# 3                 1.0            0.107143              8.261367
# 4                 1.0            0.166667              6.370760
# 5                 1.0            0.000000              1.926030
# 6                 1.0            0.000000              1.000000
#
#    weighted_mean_entropy  weighted_median_entropy  weighted_mad_entropy  \
# 0               0.000000                 0.000000              0.000000
# 1               1.060222                 1.000000              0.584963
# 2               2.235321                 2.521928              0.521928
# 3               2.781820                 2.807355              0.598467
# 4               2.393838                 2.550341              0.550341
# 5               0.776938                 0.918296              0.540852
# 6               0.000000                 0.000000              0.000000
#
#    weighted_mean_norm_entropy  weighted_median_norm_entropy  \
# 0                    0.000000                      0.000000
# 1                    0.809524                      1.000000
# 2                    0.953190                      1.000000
# 3                    0.969564                      1.000000
# 4                    0.941851                      0.982568
# 5                    0.645127                      0.918296
# 6                    0.000000                      0.000000
#
#    weighted_mad_norm_entropy  weighted_mean_top_state_prob  \
# 0               0.000000e+00                      1.000000
# 1               0.000000e+00                      0.523810
# 2               0.000000e+00                      0.262366
# 3               2.220446e-16                      0.200837
# 4               1.743241e-02                      0.276782
# 5               8.170417e-02                      0.695082
# 6               0.000000e+00                      1.000000
#
#    weighted_median_top_state_prob  weighetd_mad_top_state_prob
# 0                        1.000000                     0.000000
# 1                        0.500000                     0.166667
# 2                        0.200000                     0.066667
# 3                        0.142857                     0.042857
# 4                        0.200000                     0.057143
# 5                        0.666667                     0.166667
# 6                        1.000000                     0.000000
