# %%
from analysis_by_dice_config import generate_metrics

# %%
df = generate_metrics(
    range(2, 3),
    range(6, 7),
)

import pandas as pd

# 1. Force all columns to show (removes the ...)
pd.set_option('display.max_columns', None)

# 2. Prevent text from being cut off inside cells
pd.set_option('display.max_colwidth', None)

# 3. View the DataFrame (use display() to force a fresh render)
display(df)
# Out:
#    num_dice  num_sides  depth  num_histories  num_states  mean_states  \
# 0         2          6      0              1           1     1.000000
# 1         2          6      1             11          21     1.909091
# 2         2          6      2            115         120     3.869565
# 3         2          6      3           1117         210     5.401970
# 4         2          6      4           9593         120     4.269884
# 5         2          6      5          62663          21     1.591609
# 6         2          6      6          62663           1     1.000000
#
#    median_states  min_states  max_states  mad_states  mean_entropy  \
# 0              1           1           1         0.0      0.000000
# 1              2           1           3         1.0      0.795899
# 2              3           1          10         2.0      1.629992
# 3              4           1          20         2.0      2.008035
# 4              4           1          15         2.0      1.700761
# 5              1           1           3         0.0      0.515944
# 6              1           1           1         0.0      0.000000
#
#    median_entropy  min_entropy  max_entropy  mad_entropy  mean_norm_entropy  \
# 0        0.000000          0.0     0.000000     0.000000           0.000000
# 1        1.000000          0.0     1.584963     0.584963           0.502156
# 2        1.584963          0.0     3.321928     0.736966           0.490676
# 3        2.000000          0.0     4.277613     0.973557           0.469429
# 4        1.918296          0.0     3.766968     0.918296           0.451493
# 5        0.000000          0.0     1.584963     0.000000           0.325525
# 6        0.000000          0.0     0.000000     0.000000           0.000000
#
#    median_norm_entropy  min_norm_entropy  max_norm_entropy  mad_norm_entropy  \
# 0             0.000000               0.0               0.0          0.000000
# 1             0.630930               0.0               1.0          0.369070
# 2             0.477121               0.0               1.0          0.221849
# 3             0.467550               0.0               1.0          0.227594
# 4             0.509241               0.0               1.0          0.243776
# 5             0.000000               0.0               1.0          0.000000
# 6             0.000000               0.0               0.0          0.000000
#
#    mean_top_state_prob  median_top_state_prob  min_top_state_prob  \
# 0             1.000000               1.000000            1.000000
# 1             0.636364               0.500000            0.333333
# 2             0.416467               0.333333            0.100000
# 3             0.354686               0.250000            0.066667
# 4             0.430964               0.333333            0.100000
# 5             0.789977               1.000000            0.333333
# 6             1.000000               1.000000            1.000000
#
#    max_top_state_prob  mad_top_state_prob  weighted_mean_states  \
# 0                 1.0            0.000000              1.000000
# 1                 1.0            0.166667              1.952381
# 2                 1.0            0.166667              3.789247
# 3                 1.0            0.107143              5.508787
# 4                 1.0            0.166667              4.245946
# 5                 1.0            0.000000              1.587835
# 6                 1.0            0.000000              1.000000
#
#    weighted_median_states  weighted_mad_states  weighted_mean_entropy  \
# 0                       1                    0               0.000000
# 1                       2                    1               0.833799
# 2                       3                    2               1.582222
# 3                       5                    2               2.040027
# 4                       4                    2               1.696117
# 5                       1                    0               0.513160
# 6                       1                    0               0.000000
#
#    weighted_median_entropy  weighted_mad_entropy  weighted_mean_norm_entropy  \
# 0                 0.000000              0.000000                    0.000000
# 1                 1.000000              0.584963                    0.526068
# 2                 1.584963              0.736966                    0.476296
# 3                 2.281036              0.696074                    0.476908
# 4                 1.918296              0.918296                    0.450261
# 5                 0.000000              0.000000                    0.323768
# 6                 0.000000              0.000000                    0.000000
#
#    weighted_median_norm_entropy  weighted_mad_norm_entropy  \
# 0                      0.000000                   0.000000
# 1                      0.630930                   0.369070
# 2                      0.477121                   0.221849
# 3                      0.533250                   0.162725
# 4                      0.509241                   0.243776
# 5                      0.000000                   0.000000
# 6                      0.000000                   0.000000
#
#    weighted_mean_top_state_prob  weighted_median_top_state_prob  \
# 0                      1.000000                        1.000000
# 1                      0.619048                        0.500000
# 2                      0.434877                        0.333333
# 3                      0.346478                        0.222222
# 4                      0.431583                        0.333333
# 5                      0.791065                        1.000000
# 6                      1.000000                        1.000000
#
#    weighted_mad_top_state_prob  average_state_variance  \
# 0                     0.000000                     3.5
# 1                     0.166667                     3.5
# 2                     0.166667                     3.5
# 3                     0.111111                     3.5
# 4                     0.166667                     3.5
# 5                     0.000000                     0.0
# 6                     0.000000                     0.0
#
#    weighted_average_state_variance  average_information_gain  \
# 0                              3.5                  0.000000
# 1                              3.5                 -0.795899
# 2                              3.5                 -0.834093
# 3                              3.5                 -0.378043
# 4                              3.5                  0.307274
# 5                              0.0                  1.184816
# 6                              0.0                  0.515944
#
#    weighted_average_information_gain
# 0                           0.000000
# 1                          -0.833799
# 2                          -0.748424
# 3                          -0.457805
# 4                           0.343910
# 5                           1.182957
# 6                           0.513160
