# %%
from analysis_by_dice_config import generate_metrics
import pandas as pd

# %%
df = generate_metrics(
    pd.read_pickle("/Users/jamesekern/pythonProjects/gamblint/research/data/game_analysis/analysis_by_history.pkl")
)

import pandas as pd

# 1. Force all columns to show (removes the ...)
pd.set_option('display.max_columns', None)

# 2. Prevent text from being cut off inside cells
pd.set_option('display.max_colwidth', None)

# 3. View the DataFrame (use display() to force a fresh render)
display(df)
# Out:
#     num_dice  num_sides  depth  num_histories  num_states  mean_states  \
# 0          1          1      0              1           1     1.000000
# 1          1          1      1              1           1     1.000000
# 2          1          2      0              1           1     1.000000
# 3          1          2      1              2           2     1.000000
# 4          1          2      2              2           2     1.000000
# 5          1          3      0              1           1     1.000000
# 6          1          3      1              3           3     1.000000
# 7          1          3      2              6           6     1.000000
# 8          1          3      3              6           6     1.000000
# 9          1          4      0              1           1     1.000000
# 10         1          4      1              4           4     1.000000
# 11         1          4      2             12          12     1.000000
# ...
